# %% [markdown]
# <a href="https://colab.research.google.com/github/JavokhirJambulov/AIapplicationSystem/blob/main/CRNN_for_IAM_Paint_IMG2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import math
import string

import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.backend import get_value, ctc_decode
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Nadam

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir lines
# !mkdir ascii
# Out:
# mkdir: cannot create directory ‘lines’: File exists
# mkdir: cannot create directory ‘ascii’: File exists

# %% [markdown]
# # Prepare dataset

# %%
# https://fki.tic.heia-fr.ch/DBs/iamDB/data/lines.tgz
# !tar -xf /content/drive/MyDrive/AI_Application/lines.tgz -C /content/lines
# https://fki.tic.heia-fr.ch/DBs/iamDB/data/ascii.tgz
# !tar -xf /content/drive/MyDrive/AI_Application/ascii.tgz -C /content/ascii

# %%
# Load labels

gt = pd.DataFrame(columns=['fn', 'value'])

with open('/content/ascii/lines.txt', 'r') as f:
  for index, row in enumerate(f):
    if row[0] == '#':
      continue
    row = row.split()
    gt.loc[gt.shape[0]] = (row[0], row[-1].replace('|', ' '))
gt.head(5)
# Out:
#             fn                                  value
# 0  a01-000u-00      A MOVE to stop Mr. Gaitskell from
# 1  a01-000u-01  nominating any more Labour life Peers
# 2  a01-000u-02   is to be made at a meeting of Labour
# 3  a01-000u-03     Ps tomorrow . Mr. Michael Foot has
# 4  a01-000u-04   put down a resolution on the subject

# %%
# Data preprocessing

def preprocess(img):
  for func in [resize_n_rotate, add_adaptiveThreshold]:
    img = func(img)
  return img


def resize_n_rotate(img, shape_to=(64, 800)):
  if img.shape[0] > shape_to[0] or img.shape[1] > shape_to[1]:
    shrink_multiplayer = min(math.floor(shape_to[0] / img.shape[0] * 100) / 100,
                             math.floor(shape_to[1] / img.shape[1] * 100) / 100)
    img = cv2.resize(img, None,
                     fx=shrink_multiplayer,
                     fy=shrink_multiplayer,
                     interpolation=cv2.INTER_AREA)

  img = cv2.copyMakeBorder(img, math.ceil(shape_to[0]/2) - math.ceil(img.shape[0]/2),
                           math.floor(shape_to[0]/2) - math.floor(img.shape[0]/2),
                           math.ceil(shape_to[1]/2) - math.ceil(img.shape[1]/2),
                           math.floor(shape_to[1]/2) - math.floor(img.shape[1]/2),
                           cv2.BORDER_CONSTANT, value=255)
  return cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)


def add_adaptiveThreshold(img):
  return cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 21, 10).astype('bool')


# Label encoding

def encode_text(texts):
  def _label_to_num(label, alphabet):
    label_num = []
    for ch in label:
      label_num.append(alphabet.find(ch))
    return np.array(label_num)

  alphabet = ''.join(sorted(pd.Series(texts).apply(list).apply(pd.Series).stack().unique()))

  nums = np.ones([len(texts), max([len(text) for text in texts])], dtype='int64') * len(alphabet)
  for i, text in enumerate(texts):
    nums[i][:len(text)] = _label_to_num(text, alphabet)

  return nums, alphabet

# %%
# Load and preprocess data
from tqdm import tqdm
import pickle
train_X, train_y = [], []

for sub_folder1 in tqdm(os.listdir('./lines')):
  for sub_folder2 in os.listdir(f'./lines/{sub_folder1}'):
    for sub_folder3 in os.listdir(f'./lines/{sub_folder1}/{sub_folder2}'):

      label = gt[gt.fn == sub_folder3[:sub_folder3.rfind('.')]].value.tolist()[0]
      if not any(list(map(lambda e: e not in string.ascii_letters + ',.\' ', label))):
        train_X.append(preprocess(cv2.imread(f'./lines/{sub_folder1}/{sub_folder2}/{sub_folder3}', 0)))
        train_y.append(gt[gt.fn == sub_folder3[:sub_folder3.rfind('.')]].value.tolist()[0])

train_X = np.array(train_X)
train_y, alphabet = encode_text(train_y)
alphabet
# Save the alphabet to a file using pickle
with open('alphabet.pkl', 'wb') as f:
    pickle.dump(alphabet, f)
# Out:
# 100%|██████████| 76/76 [01:04<00:00,  1.18it/s]

# %%
train_X, val_X, train_y, val_y  = train_test_split(train_X, train_y, test_size=0.2, random_state=42)
train_X, test_X, train_y, test_y  = train_test_split(train_X, train_y, test_size=0.25, random_state=42)

# %%
fig, axes = plt.subplots(figsize=(20, 15), ncols=2, nrows=10)

# Preprocess example

for i in range(10):
  for j in range(2):
    axes[i, j % 2].imshow(cv2.rotate(
        (train_X[i * 2 + j % 2]).astype(np.uint8),cv2.ROTATE_90_COUNTERCLOCKWISE),
        cmap='gray')

# %% [markdown]
# # Model

# %%
import tensorflow as tf
class CERMetric(tf.keras.metrics.Metric):
    """
    A custom Keras metric to compute the Character Error Rate
    """
    def __init__(self, name='CER_metric', **kwargs):
        super(CERMetric, self).__init__(name=name, **kwargs)
        self.cer_accumulator = self.add_weight(name="total_cer", initializer="zeros")
        self.counter = self.add_weight(name="cer_count", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        input_shape = K.shape(y_pred)
        input_length = tf.ones(shape=input_shape[0]) * K.cast(input_shape[1], 'float32')

        decode, log = K.ctc_decode(y_pred, input_length, greedy=True)

        decode = K.ctc_label_dense_to_sparse(decode[0], K.cast(input_length, 'int32'))
        y_true_sparse = K.ctc_label_dense_to_sparse(y_true, K.cast(input_length, 'int32'))
        y_true_sparse = tf.sparse.retain(y_true_sparse, tf.not_equal(y_true_sparse.values, tf.math.reduce_max(y_true_sparse.values)))

        decode = tf.sparse.retain(decode, tf.not_equal(decode.values, -1))
        distance = tf.edit_distance(decode, y_true_sparse, normalize=True)

        self.cer_accumulator.assign_add(tf.reduce_sum(distance))
        self.counter.assign_add(K.cast(len(y_true), 'float32'))

    def result(self):
        return tf.math.divide_no_nan(self.cer_accumulator, self.counter)

    def reset_state(self):
        self.cer_accumulator.assign(0.0)
        self.counter.assign(0.0)


def CTCLoss(y_true, y_pred):
    """
    Compute the training-time loss value
    """
    batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
    input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
    label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

    input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

    loss = K.ctc_batch_cost(y_true, y_pred, input_length, label_length)
    return loss

# %%
model = Sequential()

model.add(Conv2D(64, (5, 5), padding='same', activation=LeakyReLU(alpha=0.01), input_shape=(800, 64, 1)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (5, 5), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((1, 2)))

model.add(Conv2D(128, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))

model.add(Conv2D(256, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(512, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((1, 2)))
model.add(BatchNormalization())

model.add(Conv2D(512, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((1, 2)))

model.add(Reshape((100, 512)))

model.add(Bidirectional(LSTM(256, return_sequences=True)))
model.add(Bidirectional(LSTM(256, return_sequences=True)))

model.add(Dense(len(alphabet) + 1, activation='softmax')) # +1 for ctc blank

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 800, 64, 64)       1664
#
#  max_pooling2d (MaxPooling2  (None, 400, 32, 64)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 400, 32, 128)      204928
#
#  max_pooling2d_1 (MaxPoolin  (None, 400, 16, 128)      0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 400, 16, 128)      147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 200, 8, 128)       0
#  g2D)
#
#  batch_normalization (Batch  (None, 200, 8, 128)       512
#  Normalization)
#
#  conv2d_3 (Conv2D)           (None, 200, 8, 256)       295168
#
#  conv2d_4 (Conv2D)           (None, 200, 8, 256)       590080
#
#  max_pooling2d_3 (MaxPoolin  (None, 100, 4, 256)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 100, 4, 512)       1180160
#
#  max_pooling2d_4 (MaxPoolin  (None, 100, 2, 512)       0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 100, 2, 512)       2048
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 100, 2, 512)       2359808
#
#  max_pooling2d_5 (MaxPoolin  (None, 100, 1, 512)       0
#  g2D)
#
#  reshape (Reshape)           (None, 100, 512)          0
#
#  bidirectional (Bidirection  (None, 100, 512)          1574912
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 100, 512)          1574912
#  onal)
#
#  dense (Dense)               (None, 100, 57)           29241
#
# =================================================================
# Total params: 7961017 (30.37 MB)
# Trainable params: 7959737 (30.36 MB)
# Non-trainable params: 1280 (5.00 KB)
# _________________________________________________________________

# %%
model.compile(optimizer=Nadam(learning_rate=0.001, clipnorm=1.0), loss=CTCLoss, metrics=[CERMetric()])

# %% [markdown]
# # Train model

# %%
history = model.fit(train_X, train_y, validation_data=(val_X, val_y),
                    epochs=75, batch_size=64,
                    callbacks=[EarlyStopping(patience=10, restore_best_weights=True, monitor='val_CER_metric'),
                              ReduceLROnPlateau(factor=0.5, min_lr=1e-5, patience=4, monitor='val_CER_metric')],
                    verbose=1)
# Out:
# Epoch 1/75
# 93/93 [==============================] - 108s 776ms/step - loss: 113.2273 - CER_metric: 0.8035 - val_loss: 219.2072 - val_CER_metric: 1.0000 - lr: 0.0010
# Epoch 2/75
# 93/93 [==============================] - 57s 615ms/step - loss: 48.8886 - CER_metric: 0.3394 - val_loss: 234.7907 - val_CER_metric: 0.8508 - lr: 0.0010
# Epoch 3/75
# 93/93 [==============================] - 56s 604ms/step - loss: 25.6287 - CER_metric: 0.1805 - val_loss: 228.7619 - val_CER_metric: 0.8500 - lr: 0.0010
# Epoch 4/75
# 93/93 [==============================] - 59s 636ms/step - loss: 17.9438 - CER_metric: 0.1316 - val_loss: 110.5812 - val_CER_metric: 0.6163 - lr: 0.0010
# Epoch 5/75
# 93/93 [==============================] - 59s 632ms/step - loss: 13.4358 - CER_metric: 0.0999 - val_loss: 37.8431 - val_CER_metric: 0.2587 - lr: 0.0010
# Epoch 6/75
# 93/93 [==============================] - 59s 636ms/step - loss: 10.1532 - CER_metric: 0.0780 - val_loss: 22.9851 - val_CER_metric: 0.1554 - lr: 0.0010
# Epoch 7/75
# 93/93 [==============================] - 59s 633ms/step - loss: 7.6953 - CER_metric: 0.0613 - val_loss: 21.0437 - val_CER_metric: 0.1386 - lr: 0.0010
# Epoch 8/75
# 93/93 [==============================] - 59s 636ms/step - loss: 5.7651 - CER_metric: 0.0482 - val_loss: 21.3256 - val_CER_metric: 0.1287 - lr: 0.0010
# Epoch 9/75
# 93/93 [==============================] - 59s 632ms/step - loss: 4.4302 - CER_metric: 0.0390 - val_loss: 20.9573 - val_CER_metric: 0.1247 - lr: 0.0010
# Epoch 10/75
# 93/93 [==============================] - 59s 633ms/step - loss: 3.4241 - CER_metric: 0.0300 - val_loss: 22.6698 - val_CER_metric: 0.1253 - lr: 0.0010
# Epoch 11/75
# 93/93 [==============================] - 56s 602ms/step - loss: 2.8911 - CER_metric: 0.0248 - val_loss: 22.3932 - val_CER_metric: 0.1211 - lr: 0.0010
# Epoch 12/75
# 93/93 [==============================] - 59s 633ms/step - loss: 2.3915 - CER_metric: 0.0206 - val_loss: 23.8133 - val_CER_metric: 0.1227 - lr: 0.0010
# Epoch 13/75
# 93/93 [==============================] - 56s 607ms/step - loss: 2.1266 - CER_metric: 0.0165 - val_loss: 24.6954 - val_CER_metric: 0.1327 - lr: 0.0010
# Epoch 14/75
# 93/93 [==============================] - 56s 606ms/step - loss: 1.8074 - CER_metric: 0.0160 - val_loss: 24.0050 - val_CER_metric: 0.1183 - lr: 0.0010
# Epoch 15/75
# 93/93 [==============================] - 59s 631ms/step - loss: 1.6778 - CER_metric: 0.0138 - val_loss: 24.8304 - val_CER_metric: 0.1200 - lr: 0.0010
# Epoch 16/75
# 93/93 [==============================] - 59s 634ms/step - loss: 1.5446 - CER_metric: 0.0127 - val_loss: 25.4670 - val_CER_metric: 0.1196 - lr: 0.0010
# Epoch 17/75
# 93/93 [==============================] - 59s 633ms/step - loss: 1.4299 - CER_metric: 0.0116 - val_loss: 25.3469 - val_CER_metric: 0.1213 - lr: 0.0010
# Epoch 18/75
# 93/93 [==============================] - 59s 634ms/step - loss: 1.2865 - CER_metric: 0.0107 - val_loss: 25.4201 - val_CER_metric: 0.1188 - lr: 0.0010
# Epoch 19/75
# 93/93 [==============================] - 57s 612ms/step - loss: 0.6095 - CER_metric: 0.0043 - val_loss: 25.3361 - val_CER_metric: 0.1125 - lr: 5.0000e-04
# Epoch 20/75
# 93/93 [==============================] - 58s 629ms/step - loss: 0.3366 - CER_metric: 0.0023 - val_loss: 25.6718 - val_CER_metric: 0.1072 - lr: 5.0000e-04
# Epoch 21/75
# 93/93 [==============================] - 58s 630ms/step - loss: 0.2714 - CER_metric: 0.0018 - val_loss: 26.7433 - val_CER_metric: 0.1108 - lr: 5.0000e-04
# Epoch 22/75
# 93/93 [==============================] - 56s 602ms/step - loss: 0.2576 - CER_metric: 0.0015 - val_loss: 25.9864 - val_CER_metric: 0.1074 - lr: 5.0000e-04
# Epoch 23/75
# 93/93 [==============================] - 56s 601ms/step - loss: 0.2483 - CER_metric: 0.0016 - val_loss: 26.4850 - val_CER_metric: 0.1075 - lr: 5.0000e-04
# Epoch 24/75
# 93/93 [==============================] - 58s 627ms/step - loss: 0.2176 - CER_metric: 0.0013 - val_loss: 26.3618 - val_CER_metric: 0.1059 - lr: 5.0000e-04
# Epoch 25/75
# 93/93 [==============================] - 58s 628ms/step - loss: 0.2072 - CER_metric: 0.0012 - val_loss: 26.8414 - val_CER_metric: 0.1091 - lr: 5.0000e-04
# Epoch 26/75
# 93/93 [==============================] - 58s 628ms/step - loss: 0.2158 - CER_metric: 0.0014 - val_loss: 27.1493 - val_CER_metric: 0.1093 - lr: 5.0000e-04
# Epoch 27/75
# 93/93 [==============================] - 58s 626ms/step - loss: 0.1874 - CER_metric: 0.0011 - val_loss: 27.4571 - val_CER_metric: 0.1077 - lr: 5.0000e-04
# Epoch 28/75
# 93/93 [==============================] - 58s 628ms/step - loss: 0.1902 - CER_metric: 0.0013 - val_loss: 28.3273 - val_CER_metric: 0.1082 - lr: 5.0000e-04
# Epoch 29/75
# 93/93 [==============================] - 58s 625ms/step - loss: 0.1029 - CER_metric: 4.9603e-04 - val_loss: 26.4945 - val_CER_metric: 0.1022 - lr: 2.5000e-04
# Epoch 30/75
# 93/93 [==============================] - 56s 607ms/step - loss: 0.0454 - CER_metric: 1.7647e-04 - val_loss: 26.6105 - val_CER_metric: 0.1001 - lr: 2.5000e-04
# Epoch 31/75
# 93/93 [==============================] - 57s 608ms/step - loss: 0.0317 - CER_metric: 9.9955e-05 - val_loss: 26.6740 - val_CER_metric: 0.0988 - lr: 2.5000e-04
# Epoch 32/75
# 93/93 [==============================] - 58s 629ms/step - loss: 0.0269 - CER_metric: 1.1924e-04 - val_loss: 26.7718 - val_CER_metric: 0.0986 - lr: 2.5000e-04
# Epoch 33/75
# 93/93 [==============================] - 58s 626ms/step - loss: 0.0244 - CER_metric: 8.6093e-05 - val_loss: 26.8825 - val_CER_metric: 0.0991 - lr: 2.5000e-04
# Epoch 34/75
# 93/93 [==============================] - 58s 627ms/step - loss: 0.0230 - CER_metric: 8.7271e-05 - val_loss: 26.9171 - val_CER_metric: 0.0983 - lr: 2.5000e-04
# Epoch 35/75
# 93/93 [==============================] - 58s 628ms/step - loss: 0.0230 - CER_metric: 7.8719e-05 - val_loss: 27.0299 - val_CER_metric: 0.0988 - lr: 2.5000e-04
# Epoch 36/75
# 93/93 [==============================] - 58s 626ms/step - loss: 0.0215 - CER_metric: 7.8733e-05 - val_loss: 27.1112 - val_CER_metric: 0.0986 - lr: 2.5000e-04
# Epoch 37/75
# 93/93 [==============================] - 59s 635ms/step - loss: 0.0213 - CER_metric: 7.2885e-05 - val_loss: 27.1315 - val_CER_metric: 0.0989 - lr: 2.5000e-04
# Epoch 38/75
# 93/93 [==============================] - 59s 633ms/step - loss: 0.0201 - CER_metric: 6.9247e-05 - val_loss: 27.2797 - val_CER_metric: 0.0985 - lr: 2.5000e-04
# Epoch 39/75
# 93/93 [==============================] - 59s 633ms/step - loss: 0.0185 - CER_metric: 5.3616e-05 - val_loss: 27.2602 - val_CER_metric: 0.0991 - lr: 1.2500e-04
# Epoch 40/75
# 93/93 [==============================] - 56s 604ms/step - loss: 0.0176 - CER_metric: 4.4039e-05 - val_loss: 27.3170 - val_CER_metric: 0.0987 - lr: 1.2500e-04
# Epoch 41/75
# 93/93 [==============================] - 59s 633ms/step - loss: 0.0171 - CER_metric: 4.1635e-05 - val_loss: 27.3396 - val_CER_metric: 0.0988 - lr: 1.2500e-04
# Epoch 42/75
# 93/93 [==============================] - 59s 632ms/step - loss: 0.0168 - CER_metric: 3.1381e-05 - val_loss: 27.4123 - val_CER_metric: 0.0987 - lr: 1.2500e-04
# Epoch 43/75
# 93/93 [==============================] - 59s 632ms/step - loss: 0.0165 - CER_metric: 3.5306e-05 - val_loss: 27.4065 - val_CER_metric: 0.0987 - lr: 6.2500e-05
# Epoch 44/75
# 93/93 [==============================] - 58s 630ms/step - loss: 0.0159 - CER_metric: 2.2844e-05 - val_loss: 27.4416 - val_CER_metric: 0.0986 - lr: 6.2500e-05

# %%
fig, axes = plt.subplots(figsize=(12, 6), ncols=2, nrows=1)

axes[0].plot(history.history['loss'], label='loss')
axes[0].plot(history.history['val_loss'], label='val_loss')
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].legend()
axes[1].plot(history.history['CER_metric'], label='CER_metric')
axes[1].plot(history.history['val_CER_metric'], label='val_CER_metric')
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Character Error Rate")
axes[1].legend()

plt.show()

# %%
#model.save('./crnn.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.models import Sequential, load_model
model = load_model('/content/crnn.h5', custom_objects={'CTCLoss' : CTCLoss, 'CERMetric': CERMetric})

# %%
import math
import cv2
import numpy as np

def preprocess(img):
    for func in [resize_n_rotate, add_adaptiveThreshold]:
        img = func(img)
    return img

def resize_n_rotate(img, shape_to=(64, 800)):
    if img.shape[0] > shape_to[0] or img.shape[1] > shape_to[1]:
        shrink_multiplier = min(math.floor(shape_to[0] / img.shape[0] * 100) / 100,
                                math.floor(shape_to[1] / img.shape[1] * 100) / 100)
        img = cv2.resize(img, None,
                         fx=shrink_multiplier,
                         fy=shrink_multiplier,
                         interpolation=cv2.INTER_AREA)

    img = cv2.copyMakeBorder(img,
                             math.ceil(shape_to[0]/2) - math.ceil(img.shape[0]/2),
                             math.floor(shape_to[0]/2) - math.floor(img.shape[0]/2),
                             math.ceil(shape_to[1]/2) - math.ceil(img.shape[1]/2),
                             math.floor(shape_to[1]/2) - math.floor(img.shape[1]/2),
                             cv2.BORDER_CONSTANT, value=255)
    return cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)

def add_adaptiveThreshold(img):
    return cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 21, 10).astype('bool')

# Load the image
image_path = '/content/char.png'  # Replace with the actual path to your image
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Preprocess the image
preprocessed_image = preprocess(image)

# %%
# Replace 'preprocessed_image' with your actual preprocessed image data
image_data = np.expand_dims(preprocessed_image, axis=0)  # Add batch dimension if needed

# %%
# Later, if you want to load the alphabet from the file
with open('alphabet.pkl', 'rb') as f:
    loaded_alphabet = pickle.load(f)

# Now 'loaded_alphabet' contains the same alphabet as before
print("Loaded Alphabet:", loaded_alphabet)
# Out:
# Loaded Alphabet:  ',.ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz

# %%
from tensorflow.keras.backend import get_value, ctc_decode
# Decode label for single image

def num_to_label(num, alphabet):
    text = ""
    for ch in num:
        if ch == len(alphabet): # ctc blank
          break
        else:
          text += alphabet[ch]
    return text


# Decode labels for softmax matrix

def decode_text(nums):
  values = get_value(
      ctc_decode(nums, input_length=np.ones(nums.shape[0])*nums.shape[1],
                 greedy=True)[0][0])

  texts = []
  for i in range(nums.shape[0]):
    value = values[i]
    texts.append(num_to_label(value[value >= 0], loaded_alphabet))
  return texts

# %%
predicts = model.predict(image_data)
predicts = decode_text(predicts)
# Out:
# 1/1 [==============================] - 0s 47ms/step

# %%
print(predicts)
# Out:
# ['sokhir Hells .']

# %% [markdown]
# ## Model training results

# %%
# Test results: (loss, cer)

model.evaluate(test_X, test_y)
# Out:
# 62/62 [==============================] - 11s 147ms/step - loss: 26.6405 - CER_metric: 0.0982
# [26.640546798706055, 0.09817681461572647]

# %%
# Decode label for single image

def num_to_label(num, alphabet):
    text = ""
    for ch in num:
        if ch == len(alphabet): # ctc blank
          break
        else:
          text += alphabet[ch]
    return text


# Decode labels for softmax matrix

def decode_text(nums):
  values = get_value(
      ctc_decode(nums, input_length=np.ones(nums.shape[0])*nums.shape[1],
                 greedy=True)[0][0])

  texts = []
  for i in range(nums.shape[0]):
    value = values[i]
    texts.append(num_to_label(value[value >= 0], alphabet))
  return texts

# %%
predicts = model.predict(test_X)
predicts = decode_text(predicts)
# Out:
# 62/62 [==============================] - 6s 82ms/step

# %%
# Out:
# ['sokhir Hells .']

# %%
# Prediction results

fig, axes = plt.subplots(figsize=(30, 60), ncols=2, nrows=32)

test_X = test_X.astype('int')

# Title format: GT - Predict
for i in range(64):
  axes[i // 2, i % 2].imshow(cv2.rotate(
      (test_X[i]).astype(np.uint8),cv2.ROTATE_90_COUNTERCLOCKWISE),
      cmap='gray')
  axes[i // 2, i % 2].set_title(
      f'{num_to_label(test_y[i], alphabet)} - {predicts[i]}')
  axes[i // 2, i % 2].axis("off")
