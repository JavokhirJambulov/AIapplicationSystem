# %% [markdown]
# <a href="https://colab.research.google.com/github/JavokhirJambulov/AIapplicationSystem/blob/main/12204567_Chapter_9_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import SimpleRNN
import logging
tf.get_logger().setLevel(logging.ERROR)
EPOCHS = 100
BATCH_SIZE = 16
TRAIN_TEST_SPLIT = 0.8
MIN = 12
FILE_NAME = 'book_store_sales.csv'

def readfile(file_name):
  file = open(file_name, 'r', encoding='utf-8')
  next(file)
  data = []
  for line in (file):
    values = line.split(',')
    data.append(float(values[1]))
  file.close()
  return np.array(data, dtype=np.float32)
# Read data and split into training and test data.
sales = readfile(FILE_NAME)
months = len(sales)
split = int(months * TRAIN_TEST_SPLIT)
train_sales = sales[0:split]
test_sales = sales[split:]

# %%
# Plot dataset
x = range(len(sales))
plt.plot(x, sales, 'r-', label='book sales')
plt.title('Book store sales')
plt.axis([0, 339, 0.0, 3000.0])
plt.xlabel('Months')
plt.ylabel('Sales (millions $)')
plt.legend()
plt.show()

# %%
 # Plot naive prediction
test_output = test_sales[MIN:]
naive_prediction = test_sales[MIN-1:-1]
x = range(len(test_output))
plt.plot(x, test_output, 'g-', label='test_output')
plt.plot(x, naive_prediction, 'm-', label='naive prediction')
plt.title('Book store sales')
plt.axis([0, len(test_output), 0.0, 3000.0])
plt.xlabel('months')
plt.ylabel('Monthly book store sales')
plt.legend()
plt.show()

# %%
# Standardize train and test data.
# Use only training seasons to compute mean and stddev.
mean = np.mean(train_sales)
stddev = np.std(train_sales)
train_sales_std = (train_sales - mean)/stddev
test_sales_std = (test_sales - mean)/stddev

# %%
# Create training examples.
train_months = len(train_sales)
train_X = np.zeros((train_months-MIN, train_months-1, 1))
train_y = np.zeros((train_months-MIN, 1))
for i in range(0, train_months-MIN):
  train_X[i, -(i+MIN):, 0] = train_sales_std[0:i+MIN]
  train_y[i, 0] = train_sales_std[i+MIN]
# Create test examples.
test_months = len(test_sales)
test_X = np.zeros((test_months-MIN, test_months-1, 1))
test_y = np.zeros((test_months-MIN, 1))
for i in range(0, test_months-MIN):
  test_X[i, -(i+MIN):, 0] = test_sales_std[0:i+MIN]
  test_y[i, 0] = test_sales_std[i+MIN]

# %%
# Create RNN model
model = Sequential()
model.add(SimpleRNN(128, activation='relu',
input_shape=(None, 1)))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam',
metrics =['mean_absolute_error'])
model.summary()
history = model.fit(train_X, train_y,
validation_data
= (test_X, test_y), epochs=EPOCHS,
batch_size=BATCH_SIZE, verbose=2,
shuffle=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 128)               16640
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 16769 (65.50 KB)
# Trainable params: 16769 (65.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 17/17 - 2s - loss: 0.8734 - mean_absolute_error: 0.7001 - val_loss: 0.6649 - val_mean_absolute_error: 0.7346 - 2s/epoch - 147ms/step
# Epoch 2/100
# 17/17 - 2s - loss: 0.5471 - mean_absolute_error: 0.5629 - val_loss: 0.2363 - val_mean_absolute_error: 0.3591 - 2s/epoch - 98ms/step
# Epoch 3/100
# 17/17 - 1s - loss: 0.4352 - mean_absolute_error: 0.4697 - val_loss: 0.3073 - val_mean_absolute_error: 0.4728 - 855ms/epoch - 50ms/step
# Epoch 4/100
# 17/17 - 1s - loss: 0.2660 - mean_absolute_error: 0.3811 - val_loss: 0.1386 - val_mean_absolute_error: 0.2495 - 786ms/epoch - 46ms/step
# Epoch 5/100
# 17/17 - 1s - loss: 0.1134 - mean_absolute_error: 0.2494 - val_loss: 0.1132 - val_mean_absolute_error: 0.2518 - 879ms/epoch - 52ms/step
# Epoch 6/100
# 17/17 - 2s - loss: 0.0711 - mean_absolute_error: 0.1876 - val_loss: 0.0472 - val_mean_absolute_error: 0.1338 - 2s/epoch - 96ms/step
# Epoch 7/100
# 17/17 - 1s - loss: 0.0620 - mean_absolute_error: 0.1759 - val_loss: 0.0767 - val_mean_absolute_error: 0.1974 - 1s/epoch - 71ms/step
# Epoch 8/100
# 17/17 - 1s - loss: 0.0589 - mean_absolute_error: 0.1803 - val_loss: 0.0672 - val_mean_absolute_error: 0.1817 - 827ms/epoch - 49ms/step
# Epoch 9/100
# 17/17 - 1s - loss: 0.0464 - mean_absolute_error: 0.1574 - val_loss: 0.0727 - val_mean_absolute_error: 0.1862 - 814ms/epoch - 48ms/step
# Epoch 10/100
# 17/17 - 1s - loss: 0.0470 - mean_absolute_error: 0.1579 - val_loss: 0.0531 - val_mean_absolute_error: 0.1568 - 845ms/epoch - 50ms/step
# Epoch 11/100
# 17/17 - 1s - loss: 0.0395 - mean_absolute_error: 0.1433 - val_loss: 0.0474 - val_mean_absolute_error: 0.1477 - 776ms/epoch - 46ms/step
# Epoch 12/100
# 17/17 - 1s - loss: 0.0300 - mean_absolute_error: 0.1261 - val_loss: 0.0634 - val_mean_absolute_error: 0.1707 - 824ms/epoch - 48ms/step
# Epoch 13/100
# 17/17 - 1s - loss: 0.0313 - mean_absolute_error: 0.1311 - val_loss: 0.0472 - val_mean_absolute_error: 0.1495 - 800ms/epoch - 47ms/step
# Epoch 14/100
# 17/17 - 1s - loss: 0.0313 - mean_absolute_error: 0.1320 - val_loss: 0.0432 - val_mean_absolute_error: 0.1418 - 774ms/epoch - 46ms/step
# Epoch 15/100
# 17/17 - 1s - loss: 0.0263 - mean_absolute_error: 0.1211 - val_loss: 0.0470 - val_mean_absolute_error: 0.1549 - 788ms/epoch - 46ms/step
# Epoch 16/100
# 17/17 - 1s - loss: 0.0214 - mean_absolute_error: 0.1118 - val_loss: 0.0495 - val_mean_absolute_error: 0.1492 - 804ms/epoch - 47ms/step
# Epoch 17/100
# 17/17 - 1s - loss: 0.0332 - mean_absolute_error: 0.1308 - val_loss: 0.0667 - val_mean_absolute_error: 0.1884 - 862ms/epoch - 51ms/step
# Epoch 18/100
# 17/17 - 1s - loss: 0.0252 - mean_absolute_error: 0.1195 - val_loss: 0.0404 - val_mean_absolute_error: 0.1300 - 835ms/epoch - 49ms/step
# Epoch 19/100
# 17/17 - 1s - loss: 0.0243 - mean_absolute_error: 0.1221 - val_loss: 0.0512 - val_mean_absolute_error: 0.1617 - 1s/epoch - 60ms/step
# Epoch 20/100
# 17/17 - 2s - loss: 0.0213 - mean_absolute_error: 0.1136 - val_loss: 0.0523 - val_mean_absolute_error: 0.1575 - 2s/epoch - 97ms/step
# Epoch 21/100
# 17/17 - 1s - loss: 0.0172 - mean_absolute_error: 0.0997 - val_loss: 0.0312 - val_mean_absolute_error: 0.1159 - 1s/epoch - 67ms/step
# Epoch 22/100
# 17/17 - 1s - loss: 0.0207 - mean_absolute_error: 0.1054 - val_loss: 0.0393 - val_mean_absolute_error: 0.1287 - 800ms/epoch - 47ms/step
# Epoch 23/100
# 17/17 - 1s - loss: 0.0245 - mean_absolute_error: 0.1137 - val_loss: 0.0520 - val_mean_absolute_error: 0.1565 - 841ms/epoch - 49ms/step
# Epoch 24/100
# 17/17 - 1s - loss: 0.0250 - mean_absolute_error: 0.1232 - val_loss: 0.0474 - val_mean_absolute_error: 0.1418 - 809ms/epoch - 48ms/step
# Epoch 25/100
# 17/17 - 1s - loss: 0.0186 - mean_absolute_error: 0.1012 - val_loss: 0.0336 - val_mean_absolute_error: 0.1238 - 854ms/epoch - 50ms/step
# Epoch 26/100
# 17/17 - 1s - loss: 0.0152 - mean_absolute_error: 0.0940 - val_loss: 0.0500 - val_mean_absolute_error: 0.1493 - 807ms/epoch - 47ms/step
# Epoch 27/100
# 17/17 - 1s - loss: 0.0192 - mean_absolute_error: 0.1043 - val_loss: 0.0807 - val_mean_absolute_error: 0.2083 - 813ms/epoch - 48ms/step
# Epoch 28/100
# 17/17 - 1s - loss: 0.0216 - mean_absolute_error: 0.1117 - val_loss: 0.0518 - val_mean_absolute_error: 0.1548 - 866ms/epoch - 51ms/step
# Epoch 29/100
# 17/17 - 1s - loss: 0.0174 - mean_absolute_error: 0.0944 - val_loss: 0.0390 - val_mean_absolute_error: 0.1365 - 879ms/epoch - 52ms/step
# Epoch 30/100
# 17/17 - 1s - loss: 0.0173 - mean_absolute_error: 0.1010 - val_loss: 0.0453 - val_mean_absolute_error: 0.1464 - 807ms/epoch - 47ms/step
# Epoch 31/100
# 17/17 - 1s - loss: 0.0159 - mean_absolute_error: 0.0935 - val_loss: 0.0353 - val_mean_absolute_error: 0.1284 - 759ms/epoch - 45ms/step
# Epoch 32/100
# 17/17 - 1s - loss: 0.0159 - mean_absolute_error: 0.0914 - val_loss: 0.0392 - val_mean_absolute_error: 0.1327 - 775ms/epoch - 46ms/step
# Epoch 33/100
# 17/17 - 1s - loss: 0.0155 - mean_absolute_error: 0.0927 - val_loss: 0.0417 - val_mean_absolute_error: 0.1378 - 1s/epoch - 71ms/step
# Epoch 34/100
# 17/17 - 2s - loss: 0.0180 - mean_absolute_error: 0.0978 - val_loss: 0.0407 - val_mean_absolute_error: 0.1355 - 2s/epoch - 93ms/step
# Epoch 35/100
# 17/17 - 1s - loss: 0.0209 - mean_absolute_error: 0.1043 - val_loss: 0.0394 - val_mean_absolute_error: 0.1444 - 957ms/epoch - 56ms/step
# Epoch 36/100
# 17/17 - 1s - loss: 0.0169 - mean_absolute_error: 0.0962 - val_loss: 0.0486 - val_mean_absolute_error: 0.1532 - 784ms/epoch - 46ms/step
# Epoch 37/100
# 17/17 - 1s - loss: 0.0184 - mean_absolute_error: 0.1010 - val_loss: 0.0440 - val_mean_absolute_error: 0.1407 - 781ms/epoch - 46ms/step
# Epoch 38/100
# 17/17 - 1s - loss: 0.0152 - mean_absolute_error: 0.0930 - val_loss: 0.0519 - val_mean_absolute_error: 0.1534 - 773ms/epoch - 45ms/step
# Epoch 39/100
# 17/17 - 1s - loss: 0.0171 - mean_absolute_error: 0.0931 - val_loss: 0.0348 - val_mean_absolute_error: 0.1330 - 1s/epoch - 63ms/step
# Epoch 40/100
# 17/17 - 1s - loss: 0.0244 - mean_absolute_error: 0.1115 - val_loss: 0.0398 - val_mean_absolute_error: 0.1400 - 776ms/epoch - 46ms/step
# Epoch 41/100
# 17/17 - 1s - loss: 0.0216 - mean_absolute_error: 0.1059 - val_loss: 0.0514 - val_mean_absolute_error: 0.1514 - 797ms/epoch - 47ms/step
# Epoch 42/100
# 17/17 - 1s - loss: 0.0180 - mean_absolute_error: 0.0970 - val_loss: 0.0347 - val_mean_absolute_error: 0.1297 - 828ms/epoch - 49ms/step
# Epoch 43/100
# 17/17 - 1s - loss: 0.0133 - mean_absolute_error: 0.0859 - val_loss: 0.0550 - val_mean_absolute_error: 0.1598 - 825ms/epoch - 49ms/step
# Epoch 44/100
# 17/17 - 1s - loss: 0.0130 - mean_absolute_error: 0.0861 - val_loss: 0.0393 - val_mean_absolute_error: 0.1281 - 850ms/epoch - 50ms/step
# Epoch 45/100
# 17/17 - 1s - loss: 0.0126 - mean_absolute_error: 0.0854 - val_loss: 0.0481 - val_mean_absolute_error: 0.1583 - 774ms/epoch - 46ms/step
# Epoch 46/100
# 17/17 - 1s - loss: 0.0144 - mean_absolute_error: 0.0884 - val_loss: 0.0504 - val_mean_absolute_error: 0.1535 - 761ms/epoch - 45ms/step
# Epoch 47/100
# 17/17 - 1s - loss: 0.0162 - mean_absolute_error: 0.0898 - val_loss: 0.0402 - val_mean_absolute_error: 0.1327 - 1s/epoch - 83ms/step
# Epoch 48/100
# 17/17 - 2s - loss: 0.0146 - mean_absolute_error: 0.0894 - val_loss: 0.0416 - val_mean_absolute_error: 0.1373 - 2s/epoch - 92ms/step
# Epoch 49/100
# 17/17 - 1s - loss: 0.0126 - mean_absolute_error: 0.0824 - val_loss: 0.0396 - val_mean_absolute_error: 0.1346 - 785ms/epoch - 46ms/step
# Epoch 50/100
# 17/17 - 1s - loss: 0.0151 - mean_absolute_error: 0.0912 - val_loss: 0.0381 - val_mean_absolute_error: 0.1347 - 812ms/epoch - 48ms/step
# Epoch 51/100
# 17/17 - 1s - loss: 0.0181 - mean_absolute_error: 0.1010 - val_loss: 0.0404 - val_mean_absolute_error: 0.1403 - 790ms/epoch - 46ms/step
# Epoch 52/100
# 17/17 - 1s - loss: 0.0120 - mean_absolute_error: 0.0817 - val_loss: 0.0383 - val_mean_absolute_error: 0.1279 - 750ms/epoch - 44ms/step
# Epoch 53/100
# 17/17 - 1s - loss: 0.0139 - mean_absolute_error: 0.0869 - val_loss: 0.0461 - val_mean_absolute_error: 0.1583 - 719ms/epoch - 42ms/step
# Epoch 54/100
# 17/17 - 1s - loss: 0.0120 - mean_absolute_error: 0.0806 - val_loss: 0.0513 - val_mean_absolute_error: 0.1583 - 754ms/epoch - 44ms/step
# Epoch 55/100
# 17/17 - 1s - loss: 0.0148 - mean_absolute_error: 0.0896 - val_loss: 0.0356 - val_mean_absolute_error: 0.1364 - 801ms/epoch - 47ms/step
# Epoch 56/100
# 17/17 - 1s - loss: 0.0124 - mean_absolute_error: 0.0851 - val_loss: 0.0518 - val_mean_absolute_error: 0.1627 - 743ms/epoch - 44ms/step
# Epoch 57/100
# 17/17 - 1s - loss: 0.0114 - mean_absolute_error: 0.0795 - val_loss: 0.0437 - val_mean_absolute_error: 0.1408 - 753ms/epoch - 44ms/step
# Epoch 58/100
# 17/17 - 1s - loss: 0.0151 - mean_absolute_error: 0.0896 - val_loss: 0.0389 - val_mean_absolute_error: 0.1302 - 797ms/epoch - 47ms/step
# Epoch 59/100
# 17/17 - 1s - loss: 0.0147 - mean_absolute_error: 0.0933 - val_loss: 0.0359 - val_mean_absolute_error: 0.1275 - 792ms/epoch - 47ms/step
# Epoch 60/100
# 17/17 - 1s - loss: 0.0131 - mean_absolute_error: 0.0880 - val_loss: 0.0698 - val_mean_absolute_error: 0.1979 - 791ms/epoch - 47ms/step
# Epoch 61/100
# 17/17 - 1s - loss: 0.0119 - mean_absolute_error: 0.0839 - val_loss: 0.0437 - val_mean_absolute_error: 0.1429 - 1s/epoch - 66ms/step
# Epoch 62/100
# 17/17 - 2s - loss: 0.0119 - mean_absolute_error: 0.0791 - val_loss: 0.0374 - val_mean_absolute_error: 0.1272 - 2s/epoch - 96ms/step
# Epoch 63/100
# 17/17 - 1s - loss: 0.0126 - mean_absolute_error: 0.0828 - val_loss: 0.0480 - val_mean_absolute_error: 0.1478 - 1s/epoch - 60ms/step
# Epoch 64/100
# 17/17 - 1s - loss: 0.0114 - mean_absolute_error: 0.0804 - val_loss: 0.0521 - val_mean_absolute_error: 0.1637 - 807ms/epoch - 47ms/step
# Epoch 65/100
# 17/17 - 1s - loss: 0.0100 - mean_absolute_error: 0.0772 - val_loss: 0.0409 - val_mean_absolute_error: 0.1315 - 853ms/epoch - 50ms/step
# Epoch 66/100
# 17/17 - 1s - loss: 0.0088 - mean_absolute_error: 0.0697 - val_loss: 0.0397 - val_mean_absolute_error: 0.1352 - 856ms/epoch - 50ms/step
# Epoch 67/100
# 17/17 - 1s - loss: 0.0105 - mean_absolute_error: 0.0763 - val_loss: 0.0475 - val_mean_absolute_error: 0.1483 - 761ms/epoch - 45ms/step
# Epoch 68/100
# 17/17 - 1s - loss: 0.0101 - mean_absolute_error: 0.0789 - val_loss: 0.0383 - val_mean_absolute_error: 0.1357 - 747ms/epoch - 44ms/step
# Epoch 69/100
# 17/17 - 1s - loss: 0.0108 - mean_absolute_error: 0.0782 - val_loss: 0.0446 - val_mean_absolute_error: 0.1434 - 782ms/epoch - 46ms/step
# Epoch 70/100
# 17/17 - 1s - loss: 0.0095 - mean_absolute_error: 0.0744 - val_loss: 0.0593 - val_mean_absolute_error: 0.1683 - 839ms/epoch - 49ms/step
# Epoch 71/100
# 17/17 - 1s - loss: 0.0107 - mean_absolute_error: 0.0785 - val_loss: 0.0417 - val_mean_absolute_error: 0.1355 - 819ms/epoch - 48ms/step
# Epoch 72/100
# 17/17 - 1s - loss: 0.0113 - mean_absolute_error: 0.0751 - val_loss: 0.0443 - val_mean_absolute_error: 0.1415 - 818ms/epoch - 48ms/step
# Epoch 73/100
# 17/17 - 1s - loss: 0.0113 - mean_absolute_error: 0.0778 - val_loss: 0.0452 - val_mean_absolute_error: 0.1433 - 801ms/epoch - 47ms/step
# Epoch 74/100
# 17/17 - 1s - loss: 0.0153 - mean_absolute_error: 0.0852 - val_loss: 0.0654 - val_mean_absolute_error: 0.1889 - 842ms/epoch - 50ms/step
# Epoch 75/100
# 17/17 - 1s - loss: 0.0099 - mean_absolute_error: 0.0757 - val_loss: 0.0432 - val_mean_absolute_error: 0.1410 - 1s/epoch - 62ms/step
# Epoch 76/100
# 17/17 - 2s - loss: 0.0098 - mean_absolute_error: 0.0746 - val_loss: 0.0404 - val_mean_absolute_error: 0.1420 - 2s/epoch - 142ms/step
# Epoch 77/100
# 17/17 - 1s - loss: 0.0094 - mean_absolute_error: 0.0698 - val_loss: 0.0473 - val_mean_absolute_error: 0.1483 - 819ms/epoch - 48ms/step
# Epoch 78/100
# 17/17 - 1s - loss: 0.0088 - mean_absolute_error: 0.0682 - val_loss: 0.0409 - val_mean_absolute_error: 0.1401 - 783ms/epoch - 46ms/step
# Epoch 79/100
# 17/17 - 1s - loss: 0.0082 - mean_absolute_error: 0.0693 - val_loss: 0.0551 - val_mean_absolute_error: 0.1548 - 735ms/epoch - 43ms/step
# Epoch 80/100
# 17/17 - 1s - loss: 0.0151 - mean_absolute_error: 0.0880 - val_loss: 0.0531 - val_mean_absolute_error: 0.1617 - 810ms/epoch - 48ms/step
# Epoch 81/100
# 17/17 - 1s - loss: 0.0155 - mean_absolute_error: 0.0895 - val_loss: 0.0646 - val_mean_absolute_error: 0.1803 - 798ms/epoch - 47ms/step
# Epoch 82/100
# 17/17 - 1s - loss: 0.0148 - mean_absolute_error: 0.0902 - val_loss: 0.0393 - val_mean_absolute_error: 0.1307 - 861ms/epoch - 51ms/step
# Epoch 83/100
# 17/17 - 1s - loss: 0.0119 - mean_absolute_error: 0.0816 - val_loss: 0.0395 - val_mean_absolute_error: 0.1368 - 823ms/epoch - 48ms/step
# Epoch 84/100
# 17/17 - 1s - loss: 0.0089 - mean_absolute_error: 0.0724 - val_loss: 0.0400 - val_mean_absolute_error: 0.1264 - 770ms/epoch - 45ms/step
# Epoch 85/100
# 17/17 - 1s - loss: 0.0092 - mean_absolute_error: 0.0712 - val_loss: 0.0437 - val_mean_absolute_error: 0.1427 - 717ms/epoch - 42ms/step
# Epoch 86/100
# 17/17 - 1s - loss: 0.0087 - mean_absolute_error: 0.0711 - val_loss: 0.0421 - val_mean_absolute_error: 0.1391 - 744ms/epoch - 44ms/step
# Epoch 87/100
# 17/17 - 1s - loss: 0.0142 - mean_absolute_error: 0.0853 - val_loss: 0.0725 - val_mean_absolute_error: 0.1838 - 756ms/epoch - 44ms/step
# Epoch 88/100
# 17/17 - 1s - loss: 0.0148 - mean_absolute_error: 0.0937 - val_loss: 0.0445 - val_mean_absolute_error: 0.1542 - 750ms/epoch - 44ms/step
# Epoch 89/100
# 17/17 - 1s - loss: 0.0115 - mean_absolute_error: 0.0846 - val_loss: 0.0342 - val_mean_absolute_error: 0.1239 - 1s/epoch - 65ms/step
# Epoch 90/100
# 17/17 - 2s - loss: 0.0110 - mean_absolute_error: 0.0782 - val_loss: 0.0427 - val_mean_absolute_error: 0.1382 - 2s/epoch - 91ms/step
# Epoch 91/100
# 17/17 - 1s - loss: 0.0118 - mean_absolute_error: 0.0821 - val_loss: 0.0489 - val_mean_absolute_error: 0.1496 - 931ms/epoch - 55ms/step
# Epoch 92/100
# 17/17 - 1s - loss: 0.0096 - mean_absolute_error: 0.0739 - val_loss: 0.0396 - val_mean_absolute_error: 0.1323 - 770ms/epoch - 45ms/step
# Epoch 93/100
# 17/17 - 1s - loss: 0.0093 - mean_absolute_error: 0.0730 - val_loss: 0.0451 - val_mean_absolute_error: 0.1431 - 726ms/epoch - 43ms/step
# Epoch 94/100
# 17/17 - 1s - loss: 0.0097 - mean_absolute_error: 0.0762 - val_loss: 0.0415 - val_mean_absolute_error: 0.1407 - 780ms/epoch - 46ms/step
# Epoch 95/100
# 17/17 - 1s - loss: 0.0080 - mean_absolute_error: 0.0675 - val_loss: 0.0405 - val_mean_absolute_error: 0.1324 - 775ms/epoch - 46ms/step
# Epoch 96/100
# 17/17 - 1s - loss: 0.0100 - mean_absolute_error: 0.0721 - val_loss: 0.0446 - val_mean_absolute_error: 0.1435 - 783ms/epoch - 46ms/step
# Epoch 97/100
# 17/17 - 1s - loss: 0.0087 - mean_absolute_error: 0.0691 - val_loss: 0.0580 - val_mean_absolute_error: 0.1602 - 834ms/epoch - 49ms/step
# Epoch 98/100
# 17/17 - 1s - loss: 0.0073 - mean_absolute_error: 0.0638 - val_loss: 0.0410 - val_mean_absolute_error: 0.1313 - 784ms/epoch - 46ms/step
# Epoch 99/100
# 17/17 - 1s - loss: 0.0080 - mean_absolute_error: 0.0661 - val_loss: 0.0447 - val_mean_absolute_error: 0.1401 - 719ms/epoch - 42ms/step
# Epoch 100/100
# 17/17 - 1s - loss: 0.0080 - mean_absolute_error: 0.0671 - val_loss: 0.0436 - val_mean_absolute_error: 0.1444 - 757ms/epoch - 45ms/step

# %%
 # Use trained model to predict the test data
predicted_test = model.predict(test_X, len(test_X))
predicted_test = np.reshape(predicted_test,
(len(predicted_test)))
predicted_test = predicted_test * stddev + mean
# Plot test prediction.
x = range(len(test_sales)-MIN)
plt.plot(x, predicted_test, 'm-',
label='predicted test_output')
plt.plot(x, test_sales[-(len(test_sales)-MIN):],
'g-', label='actual test_output')
plt.title('Book sales')
plt.axis([0, 55, 0.0, 3000.0])
plt.xlabel('months')
plt.ylabel('Predicted book sales')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 196ms/step
